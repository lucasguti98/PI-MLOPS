# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("steam_games_clean.csv")

# %% [markdown]
# ## Análisis de variables numéricas

# %%
df.head()
# Out:
#                                               genres                    title  \
# 0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...      Lost Summoner Kitty
# 1       ['Free to Play', 'Indie', 'RPG', 'Strategy']                Ironbound
# 2  ['Casual', 'Free to Play', 'Indie', 'Simulatio...  Real Pool 3D - Poolians
# 3                  ['Action', 'Adventure', 'Casual']                  弹炸人2222
# 4              ['Action', 'Adventure', 'Simulation']    Battle Royale Trainer
#
#   release_date  price      id            developer
# 0   2018-01-04   4.99  761140            Kotoshiro
# 1   2018-01-04   0.00  643980     Secret Level SRL
# 2   2017-07-24   0.00  670290         Poolians.com
# 3   2017-12-07   0.99  767400                 彼岸领域
# 4   2018-01-04   3.99  772540  Trickjump Games Ltd

# %%
df["price"].describe()
# Out:
# count    27617.000000
# mean         9.004576
# std         15.956906
# min          0.000000
# 25%          2.990000
# 50%          4.990000
# 75%          9.990000
# max        995.000000
# Name: price, dtype: float64

# %%
#Probé con varios plots pero al estar la mayoría de valores en un rango pequeño no me revelaban mucho pero encontré este gráfico que sirve bastante.

precios = df['price']
precios_ordenados = np.sort(precios)

plt.plot(precios_ordenados, np.arange(1, len(precios_ordenados) + 1) / len(precios_ordenados), marker='.', linestyle='none')
plt.xlabel('Precios')
plt.ylabel('ECDF')
plt.title('Función de Distribución Acumulativa Empírica (ECDF) de Precios')
plt.grid(True)
plt.show()

# %%
df["price"].value_counts()
# Out:
# price
# 4.99      3860
# 9.99      3584
# 2.99      3178
# 0.99      2478
# 1.99      2251
#           ...
# 4.68         1
# 131.40       1
# 44.98        1
# 202.76       1
# 160.91       1
# Name: count, Length: 135, dtype: int64

# %%
#Parecen haber valores demasiado elevados por lo que chequié en la database de steam y hay algunos juegos que pude encontrar un 
#un precio real mas bajo por lo que los cambié manualmente.
df[df["price"]>250]
# Out:
#                                                   genres  \
# 2243                                      ['Simulation']
# 4081   ['Animation &amp; Modeling', 'Design &amp; Ill...
# 7939   ['Animation &amp; Modeling', 'Design &amp; Ill...
# 7940   ['Animation &amp; Modeling', 'Design &amp; Ill...
# 8210                                ['Video Production']
# 10151  ['Animation &amp; Modeling', 'Design &amp; Ill...
# 10448  ['Animation &amp; Modeling', 'Design &amp; Ill...
# 11777                               ['Video Production']
# 12235  ['Animation &amp; Modeling', 'Design &amp; Ill...
# 13519           ['Audio Production', 'Video Production']
# 15000   ['Animation &amp; Modeling', 'Video Production']
# 15122   ['Free to Play', 'Massively Multiplayer', 'RPG']
# 22730  ['Animation &amp; Modeling', 'Design &amp; Ill...
# 25207  ['Animation &amp; Modeling', 'Education', 'Uti...
#
#                                                    title release_date   price  \
# 2243                          X-Plane 10 Global - 64 Bit   2014-07-14  771.71
# 4081                                       MODO indie 10   2015-09-24  299.99
# 7939                           GameMaker Studio 2 Mobile   2017-03-08  399.99
# 7940                              GameMaker Studio 2 UWP   2017-03-08  399.99
# 8210                    MAGIX Video Pro X8 Steam Edition   2017-04-11  399.00
# 10151                     Marvelous Designer 7 For Steam   2017-09-28  320.00
# 10448    Strata Spaces VR – Professional Edition Upgrade   2017-10-26  995.00
# 11777                   MAGIX Video Pro X9 Steam Edition   2017-11-28  399.00
# 12235  CUR3D Maker Edition - Permission for commercia...   2017-11-06  499.99
# 13519                    VEGAS Pro 15 Edit Steam Edition   2017-09-05  399.00
# 15000                          FaceRig Studio - Personal   2017-05-17  299.99
# 15122                             EVE Online: 15400 PLEX   2017-05-09  499.99
# 22730                  CopperCube - Professional Edition   2015-04-24  289.99
# 25207             Clickteam Fusion 2.5 Developer Upgrade   2014-01-27  299.99
#
#            id                   developer
# 2243   292180            Laminar Research
# 4081   401090                 The Foundry
# 7939   585620             YoYo Games Ltd.
# 7940   585610             YoYo Games Ltd.
# 8210   598860         MAGIX Software GmbH
# 10151  707410         CLO Virtual Fashion
# 10448  719000  Strata Mixed Reality, Inc.
# 11777  750840         MAGIX Software GmbH
# 12235  691560             RUHRSOURCE GmbH
# 13519  689790         MAGIX Software GmbH
# 15000  571690            Holotech Studios
# 15122  629796                         CCP
# 22730  366190                Ambiera e.U.
# 25207  267810                   Clickteam

# %%
df.loc[90702, 'price'] = 19.99
df.loc[92755, 'price'] = 14.99
df.loc[97384, 'price'] = 74.99
df.loc[97385, 'price'] = 74.99
df.loc[97727, 'price'] = 79.80
df.loc[100045, 'price'] = 199.99
df.loc[102614, 'price'] = 199.99
df.loc[104156, 'price'] = 78.98
df.loc[105948, 'price'] = 149.99
df.loc[115162, 'price'] = 19.99
df.loc[97384, 'price'] = 74.99
df.loc[97384, 'price'] = 74.99

# %%
#Me quedo con los valores de precio menores a 200 para hacer mas análisis.
df = df[df['price'] <= 200]

# %%
sns.boxplot(y=df.price)
plt.ylabel('Price')
plt.title('Box Plot of Prices')
plt.show()

# %% [markdown]
# ## Análisis de variables categóricas

# %%
#Desgloso los valores de la columna genres
genres = df['genres'].str.split(',').explode().str.strip()
genres = genres.str.replace(r"[\[\]']", '', regex=True)

# %%
#Cuento cuantos juegos hay para cada género y hago un ranking.
genres_count = genres.value_counts()
plt.figure(figsize=(10, 6))
genres_count.head(10).sort_values().plot(kind='barh',edgecolor='black')
plt.xlabel('Número de juegos')
plt.title('Top 10 géneros')
plt.show()

# %%
#Creo una columna de año para hacer análisis temporal.

df['release_year'] = pd.to_datetime(df['release_date']).dt.year
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 #Creo una columna de año para hacer análisis temporal.
# ----> 3 df['release_year'] = pd.to_datetime(df['release_date']).dt.year
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "Jun 2009" doesn't match format "%Y-%m-%d", at position 220. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
#Parece haber valores con formato incorrecto por lo que los selecciono para ver si son muchos.
patron = r'^\d{4}-\d{2}-\d{2}$'
valid_dates = df[pd.notna(df['release_date'])]
fechas_validas = valid_dates[valid_dates['release_date'].str.match(patron)]
fechas_invalidas = df[~df.index.isin(fechas_validas.index)]

# %%
fechas_invalidas
# Out:
#                                                    genres  \
# 220                                ['Adventure', 'Indie']
# 463                                   ['RPG', 'Strategy']
# 466                                   ['RPG', 'Strategy']
# 467                                   ['RPG', 'Strategy']
# 550                                            ['Racing']
# 2429    ['Action', 'Indie', 'Racing', 'Simulation', 'S...
# 3242                              ['Action', 'Adventure']
# 5429    ['Action', 'Adventure', 'Casual', 'Indie', 'St...
# 5975                                        ['Utilities']
# 9138                            ['Indie', 'Early Access']
# 11218                    ['Adventure', 'Casual', 'Indie']
# 13370                                   ['Action', 'RPG']
# 14197                                 ['Casual', 'Indie']
# 15470   ['Action', 'Casual', 'Indie', 'Sports', 'Early...
# 16496   ['Action', 'Casual', 'Free to Play', 'Massivel...
# 17465                             ['Action', 'Adventure']
# 17521                                 ['Action', 'Indie']
# 17853         ['Adventure', 'Indie', 'RPG', 'Simulation']
# 18840                    ['Action', 'Adventure', 'Indie']
# 19331                                          ['Action']
# 21746                    ['Action', 'Adventure', 'Indie']
# 22397                          ['Action', 'Free to Play']
# 22546                              ['Adventure', 'Indie']
# 23117   ['Audio Production', 'Utilities', 'Video Produ...
# 23460                                    ['Free to Play']
# 23863                                          ['Action']
# 24181                                        ['Strategy']
# 24469   ['Adventure', 'Casual', 'Free to Play', 'Massi...
# 24686          ['Action', 'Adventure', 'Casual', 'Indie']
# 25932                                          ['Action']
# 26080                                             ['RPG']
# 26994                                          ['Action']
# 27036                                      ['Simulation']
# 27077                          ['Strategy', 'Simulation']
# 27130                                          ['Casual']
# 27178                                          ['Action']
# 27228                                ['Sports', 'Action']
# 27494                                          ['Action']
# 27524                                 ['Action', 'Indie']
# 90702                                                 NaN
# 92755                                                 NaN
# 97384                                                 NaN
# 97385                                                 NaN
# 2429     18.99   308080.0                                             Gugila
# 3242     14.99   324344.0  Ubisoft Montreal, Red Storm, Shanghai, Toronto...
# 5429      4.99   463240.0                                    IndieKeep Games
# 5975      0.00   496100.0                                         Futuremark
# 9138      4.99   665780.0                                       Jello Godfri
# 11218     0.99   761310.0                               Onlyjoy`s production
# 13370    59.99   579180.0                                       Nihon Falcom
# 14197     0.00   676890.0                                      Artur Rezende
# 15470    24.99   521330.0                   Strength in Numbers Studios, Inc
# 16496     0.00   534820.0                                         Net Dragon
# 17465    99.99   517831.0                                      Infinity Ward
# 17521     0.00   552680.0                                     VitaliZelenyuk
# 17853    19.99   417990.0                                  Tall Tail Studios
# 18840    29.99   384490.0                                Harebrained Schemes
# 19331    24.99   442010.0                                 FromSoftware, Inc.
# 21746     0.99   397700.0                                  Bloodshadow Games
# 22397     0.00   333930.0                                      Splash Damage
# 22546    14.99   307580.0                                   Technocrat Games
# 23117    64.99   315200.0                                   Holotech Studios
# 23460     0.00   335150.0                                           Gameguyz
# 23863    49.99   317660.0                  Sledgehammer Games,Raven Software
# 24181    24.99   292990.0                         KOEI TECMO GAMES CO., LTD.
# 24469     0.00   268420.0                                           X-Legend
# 24686     6.99   263700.0                                    Angry Mob Games
# 25932    49.99  2028062.0                                           Treyarch
# 26080    14.99   223330.0                                   BlackMark Studio
# 26994     7.49    10697.0                                          Rebellion
# 27036     9.99    48110.0                                    Ubisoft Romania
# 27077     6.99    23455.0                                    Haemimont Games
# 27130     9.99    40200.0                                         Sabi Games
# 27178    19.99    37700.0                                       8monkey Labs
# 27228     0.00    17730.0                                 Smashball Labs LLC
# 27494    19.99   575301.0                                           CI Games
# 27524    20.00   519860.0                                    David Szymanski
# 90702    19.99        NaN                                                NaN
# 92755    14.99        NaN                                                NaN
# 97384    74.99        NaN                                                NaN
# 97385    74.99        NaN                                                NaN
# 97727    79.80        NaN                                                NaN
# 100045  199.99        NaN                                                NaN
# 102614  199.99        NaN                                                NaN
# 104156   78.98        NaN                                                NaN
# 105948  149.99        NaN                                                NaN
# 115162   19.99        NaN                                                NaN

# %%
#Parecen ser pocas por lo que me quedo con el resto.

df = fechas_validas

# %%
df['release_year'] = pd.to_datetime(df['release_date']).dt.year
año_estreno_cuenta = df['release_year'].value_counts().sort_index()
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_8516\816798694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_year'] = pd.to_datetime(df['release_date']).dt.year

# %%
plt.figure(figsize=(12, 6))
plt.bar(año_estreno_cuenta.index, año_estreno_cuenta.values)
plt.xlabel('Año de estreno')
plt.ylabel('Cantidad de juegos')
plt.title('Juegos por año')
plt.xlim(1994, 2023)
plt.xticks(rotation=45)
plt.show()

# %%
#Dropeo la columna release_date y me quedo con el dataframe para realizar los endpoints
df = df.drop(columns="release_date")
df.to_csv('steam_games_clean.csv', index=False)
